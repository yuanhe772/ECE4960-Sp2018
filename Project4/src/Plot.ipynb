# %% [markdown]
# ## ECE 4960 - Project 4 - Plotting Script

# %%
#### import numpy as np
import matplotlib.pyplot as plt

# Plot 1 curve
def plot1(x, y, x_name, y_name, fig_name):
    plt.figure(figsize=(9, 4))
    plt.rcParams.update({'font.size':12})
    plt.plot(x, y, color="C2", marker = "o", linewidth=1.5)
    plt.xlabel(x_name)
    plt.ylabel(y_name)
    plt.title(fig_name)
    plt.legend()
    plt.grid()
    plt.show()


# Plot 3 curves
def plot3(x, y1, y2, y3, x_name, y_name, curve1_name, curve2_name, curve3_name, fig_name):
    plt.figure(figsize=(9, 6))
    plt.rcParams.update({'font.size':12})
    plt.plot(x, y1, color="C0", label=curve1_name, marker = "o", linewidth=1.5)
    plt.plot(x, y2, color="C1", label=curve2_name, marker = "o", linewidth=1.5)
    plt.plot(x, y3, color="C2", label=curve3_name, marker = "o", linewidth=1.5)
    plt.xlabel(x_name)
    plt.ylabel(y_name)
    plt.title(fig_name)
    plt.legend()
    plt.grid()
    plt.show()
       
# Plot 6 curves
def plot6(x, x_name, y1, name1, y2, name2, y3, name3, y4, name4, y5,name5, y6, name6, y_name, fig_name):
    plt.figure(figsize=(12, 9))
    plt.rcParams.update({'font.size':12})
    plt.plot(x, y1, color="C0", label=name1, linewidth=3)
    plt.plot(x, y2, color="C0", label=name2, linewidth=3, linestyle='--')
    plt.plot(x, y3, color="C1", label=name3, linewidth=2.5)
    plt.plot(x, y4, color="C1", label=name4, linewidth=2.5, linestyle='--')
    plt.plot(x, y5, color="C4", label=name5, linewidth=1.5)
    plt.plot(x, y6, color="C4", label=name6, linewidth=1.5, linestyle='--')
    plt.xlabel(x_name)
    plt.ylabel(y_name)
    plt.title(fig_name)
    plt.legend(bbox_to_anchor=(1.18, 1.01))
    plt.grid()
    plt.show()
    
    
# Task 3:
print("\n\n-------------------------- Task 3: --------------------------")
t = range(1,12)
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/ForwardEulerTest.txt')  
FEerror = data[1:,1]
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/RK4Test.txt')  
RK4error = data[1:,1]
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/RK34Test.txt')  
RK34error = data[1:,1]
plot3(t, FEerror, RK4error, RK34error, "t", "ODE solver's error%", "Forward Euler", "RK4", "RK34", "Fig. [1]\nODE solver's error% vs time")
plot1(t, RK34error, "t", "RK34's error%", "Fig. [1](b)\nZoom in for RK34's error% VS. t")




# Task 4:
print("\n\n-------------------------- Task 4: --------------------------")


# 1ns:
t = range(0,102)
# Forward Euler:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/Circuit1_forwardEuler_1ns.txt', delimiter='\t')  
V1_FE, V2_FE = data[:, 0], data[:,1]
# RK4:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/Circuit1_RK4_1ns.txt', delimiter='\t')  
V1_RK4, V2_RK4 = data[:, 0], data[:,1]
# RK34 with time adaption:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/Circuit1_RK34_1ns.txt', delimiter='\t')  
V1_RK34, V2_RK34 = data[:, 0], data[:,1]
plot6(t,"t (ns)", V1_FE, "V1_FE",  V2_FE, "V2_FE", V1_RK4,"V1_RK4", V2_RK4,"V2_RK4", V1_RK34, "V1_RK34",
     V2_RK34, "V2_RK34", "Voltage (V)", "Fig. [2]\nSimulaion of circuit 1 (time step = 1ns)")

# 0.2ns:
t = np.arange(0.0, 100.2, 0.2)
# Forward Euler:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/Circuit1_forwardEuler_02ns.txt', delimiter='\t')  
V1_FE, V2_FE = data[:, 0], data[:,1]
# RK4:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/Circuit1_RK4_02ns.txt', delimiter='\t')  
V1_RK4, V2_RK4 = data[:, 0], data[:,1]
# RK34 with time adaption:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/Circuit1_RK34_02ns.txt', delimiter='\t')  
V1_RK34, V2_RK34 = data[:, 0], data[:,1]
plot6(t,"t (ns)", V1_FE, "V1_FE",  V2_FE, "V2_FE", V1_RK4,"V1_RK4", V2_RK4,"V2_RK4", V1_RK34, "V1_RK34",
     V2_RK34, "V2_RK34", "Voltage (V)", "Fig. [3]\nSimulaion of circuit 1(time step = 0.2ns)")




print("\n\n-------------------------- Task 5: --------------------------")
# 1ns:
t = range(0,102)
# Forward Euler:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/Circuit2_forwardEuler_1ns.txt', delimiter='\t')  
V1_FE, V2_FE = data[:, 0], data[:,1]
# RK4:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/Circuit2_RK4_1ns.txt', delimiter='\t')  
V1_RK4, V2_RK4 = data[:, 0], data[:,1]
# RK34 with time adaption:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/Circuit2_RK34_1ns.txt')  
V1_RK34, V2_RK34 = data[:, 0], data[:,1]
plot6(t,"t (ns)", V1_FE, "V1_FE",  V2_FE, "V2_FE", V1_RK4,"V1_RK4", V2_RK4,"V2_RK4", V1_RK34, "V1_RK34",
     V2_RK34, "V2_RK34", "Voltage (V)", "Fig. [4]\nSimulaion of circuit 2(time step = 1ns)")

# 0.2ns:
t = np.arange(0.0, 100.2, 0.2)
# Forward Euler:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/Circuit2_forwardEuler_02ns.txt', delimiter='\t')  
V1_FE, V2_FE = data[:, 0], data[:,1]
# RK4:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/Circuit2_RK4_02ns.txt', delimiter='\t')  
V1_RK4, V2_RK4 = data[:, 0], data[:,1]
# RK34 with time adaption:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/Circuit2_RK34_02ns.txt')  
V1_RK34, V2_RK34 = data[:, 0], data[:,1]
plot6(t,"t (ns)", V1_FE, "V1_FE",  V2_FE, "V2_FE", V1_RK4,"V1_RK4", V2_RK4,"V2_RK4", V1_RK34, "V1_RK34",
     V2_RK34, "V2_RK34", "Voltage (V)", "Fig. [5]\nSimulaion of circuit 2(time step = 0.2ns)")
# Out:
# -------------------------- Task 3: --------------------------
# -------------------------- Task 4: --------------------------
# -------------------------- Task 5: --------------------------
