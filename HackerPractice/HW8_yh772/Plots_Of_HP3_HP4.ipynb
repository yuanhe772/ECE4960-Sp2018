# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

# x-axe
objects = []
for i in range(20):
    objects.append((i+1)*0.5)

# P(v)
y_pos = np.arange(len(objects))
averagePV = [0.19555858638715581, 0.18566299848556317, 0.17499742523016748, 0.16416326215433247, 0.15607935778507184, 0.1458084860083377, 0.13521143003893757, 0.1234669196758893, 0.11225190663567519, 0.10023007891346625, 0.09175965157102733, 0.08237602308428232, 0.07312886999198998, 0.06474316466471261, 0.054694342632196774, 0.04590598480173774, 0.03559459213255084, 0.02465508268003797, 0.015056424277499465, 0.005298695678551472]

 
plt.bar(y_pos, averagePV, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('p(v)')
plt.xlabel('v')
plt.title('p(v) - v, with bin size = 0.5')
plt.show()

# F(v)
averageFV = [3.937954622390549E-6, 6.071124218439694E-4, 6.600376264470631E-4, 0.002432015988927394, 0.003999982828112425, 0.004006632534851784, 0.005124892336687337, 0.005184359479628253, 0.00708243699660116, 0.009014934013033105, 0.01182770954023693, 0.013116909286832512, 0.01352636829894327, 0.014011576321699248, 0.014235614235648675, 0.015222829763511636, 0.015263526550555628, 0.015854482482456245, 0.015914545867215635, 0.01655828906100787]
plt.bar(y_pos, averageFV, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('F(v)')
plt.xlabel('v')
plt.title('F(v) - v, with bin size = 0.5')
plt.show()
